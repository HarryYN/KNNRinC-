# %% [markdown]
# This file is used to generate the test data

# %%
# import the needed packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# define the main function 
def main():
    print("python main function")

# %%
# run the main function 
if __name__ == '__main__':
    main()
